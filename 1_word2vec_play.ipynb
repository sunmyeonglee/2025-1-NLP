# %%
import gensim
import numpy as np
import pprint as pp

# %%
import gensim.downloader
list(gensim.downloader.info()['models'].keys())
# Out:
# ['fasttext-wiki-news-subwords-300',
#  'conceptnet-numberbatch-17-06-300',
#  'word2vec-ruscorpora-300',
#  'word2vec-google-news-300',
#  'glove-wiki-gigaword-50',
#  'glove-wiki-gigaword-100',
#  'glove-wiki-gigaword-200',
#  'glove-wiki-gigaword-300',
#  'glove-twitter-25',
#  'glove-twitter-50',
#  'glove-twitter-100',
#  'glove-twitter-200',
#  '__testing_word2vec-matrix-synopsis']

# %%
your_model_code = 'glove-twitter-25' # select among the model code aboves
model = gensim.downloader.load(your_model_code) # download and load the model. It can take some time
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
your_word = 'ux'
model[your_word]
# Out:
# array([ 0.25732 ,  0.29221 , -1.0925  , -0.72368 ,  1.1324  , -0.37348 ,
#        -0.05374 , -0.85274 ,  1.2655  , -1.1442  , -0.64623 ,  0.14275 ,
#        -1.7615  , -0.62936 ,  0.293   , -0.25254 , -0.16609 ,  0.4412  ,
#         0.87821 ,  1.0142  , -0.34219 , -1.2971  , -1.0342  , -0.056552,
#        -0.7041  ], dtype=float32)

# %%
model.most_similar(your_word)
# Out:
# [('crm', 0.9309028387069702),
#  ('bigdata', 0.9109833240509033),
#  ('enterprise', 0.910386323928833),
#  ('analytics', 0.9094794392585754),
#  ('sharepoint', 0.9074854254722595),
#  ('gamification', 0.9064902663230896),
#  ('joomla', 0.9019238948822021),
#  ('mktg', 0.8965912461280823),
#  ('drupal', 0.893639326095581),
#  ('ppc', 0.8879729509353638)]

# %%
import matplotlib.pyplot as plt

plt.plot(model['design'])
plt.plot(model['art'])
plt.plot(model['orange'])

# %%
# commit test
